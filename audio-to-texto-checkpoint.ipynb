# %%
import speech_recognition as sr

# %%
filename = "16-122828-0002.wav"

# %%
# initialize the recognizer
r = sr.Recognizer()

# %%
# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0b7b7e23d743> in <module>
#       1 # open the file
# ----> 2 with sr.AudioFile(filename) as source:
#       3     # listen for the data (load audio to memory)
#       4     audio_data = r.record(source)
#       5     # recognize (convert from speech to text)
#
# ~\anaconda3\envs\trabalho_opencv\lib\site-packages\speech_recognition\__init__.py in __enter__(self)
#     201         try:
#     202             # attempt to read the file as WAV
# --> 203             self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#     204             self.little_endian = True  # RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#     205         except (wave.Error, EOFError):
#
# ~\anaconda3\envs\trabalho_opencv\lib\wave.py in open(f, mode)
#     508             mode = 'rb'
#     509     if mode in ('r', 'rb'):
# --> 510         return Wave_read(f)
#     511     elif mode in ('w', 'wb'):
#     512         return Wave_write(f)
#
# ~\anaconda3\envs\trabalho_opencv\lib\wave.py in __init__(self, f)
#     158         self._i_opened_the_file = None
#     159         if isinstance(f, str):
# --> 160             f = builtins.open(f, 'rb')
#     161             self._i_opened_the_file = f
#     162         # else, assume it is an open file object already
#
# FileNotFoundError: [Errno 2] No such file or directory: '16-122828-0002.wav'
